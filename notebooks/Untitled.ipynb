# %%
import pickle 
with open('./../transcribed_file/027.pickle', 'rb') as f:
    transcribed_result = pickle.load(f)
transcribed_result
# Out:
# {'jobName': '20200510-095215',
#  'accountId': '338452379825',
# ...
